# %%
from utilities import *
from modules_GtS import *
from framework_GtS import *
from evaluation import *
import spacy_component

# %%
client = chromadb.PersistentClient(path="./LC_QuAD2.0")
collection = client.get_collection(name="qa_collection")
results = search_chroma(client, "What is the highest temperature in Canada?", top_k=10)
context_text = context(results)
print(context_text)
print(results[0])
# Out:
# What has  location as Ontario? to SPARQL is SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/location> <http://dbpedia.org/resource/Ontario>  . }
# In how many places are the companies founded in Canada operating? to SPARQL is SELECT DISTINCT COUNT(?uri) WHERE { ?x <http://dbpedia.org/ontology/foundationPlace> <http://dbpedia.org/resource/Canada> . ?x <http://dbpedia.org/property/locations> ?uri  . }
# What river originates in Kingston Ontario? to SPARQL is SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/property/sourceLocation> <http://dbpedia.org/resource/Kingston,_Ontario>  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/River>}
# How many things have made different people living in Canada famous? to SPARQL is SELECT DISTINCT COUNT(?uri) WHERE { ?x <http://dbpedia.org/ontology/nationality> <http://dbpedia.org/resource/Canadians> . ?x <http://dbpedia.org/ontology/knownFor> ?uri  . }
# What is the river whose source is Lake Ontario? to SPARQL is SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/source> <http://dbpedia.org/resource/Lake_Ontario>  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/River>}
# Does the St lawrence river start in Kingston, Ontario? to SPARQL is ASK WHERE { <http://dbpedia.org/resource/Saint_Lawrence_River> <http://dbpedia.org/ontology/sourceMountain> <http://dbpedia.org/resource/Kingston,_Ontario> }
# What companies are located in toronto? to SPARQL is SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/locationCity> <http://dbpedia.org/resource/Toronto>  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Company>}
# Name the hockey team which has head coach as Mike babcock and is based in Toronto ? to SPARQL is SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/locationCity> <http://dbpedia.org/resource/Toronto> . ?uri <http://dbpedia.org/property/headCoach> <http://dbpedia.org/resource/Mike_Babcock>  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/HockeyTeam>}
# Where can I find companies which originated in Canada? to SPARQL is SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/ontology/foundationPlace> <http://dbpedia.org/resource/Canada> . ?x <http://dbpedia.org/property/locations> ?uri  . ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Company>}
# Ontario's ice hockey players have been a part of which teams? to SPARQL is SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/property/placeOfBirth> <http://dbpedia.org/resource/Ontario> . ?x <http://dbpedia.org/ontology/team> ?uri  . ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/IceHockeyPlayer>}
#
# {'english_text': 'What has  location as Ontario?', 'sparql_query': 'SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/location> <http://dbpedia.org/resource/Ontario>  . }', 'similarity_score': 0.4535}

# %%
llm = ChatOpenAI(
    model_name="hf.co/Qwen/Qwen2.5-1.5B-Instruct-GGUF:qwen2.5-1.5b-instruct-q8_0.gguf",
    base_url="http://localhost:11434/v1",
    openai_api_key="fhguh",
)

# %%
if __name__ == "__main__":
    initial_state = {
        "QUESTION": "Who won both Oscars and Nobel Prize?",
        "KB": "dbpedia",
        "LLM": llm,  # set your LLM object here
    }




final_state = CHAIN.invoke(initial_state)
for q in final_state.get("COMPLETED_SPARQLS", []):
    print(q)
# Out:
# I am RAG
# SELECT DISTINCT COUNT(?uri) WHERE { ?x {{Replace with URI}} {{Replace with URI}} . ?x {{Replace with URI}} ?uri  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> {{Replace with URI}}}
# SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> ?uri . ?uri <http://dbpedia.org/property/awards> 'Oscares' . ?x <http://dbpedia.org/ontology/award> '?uri'. ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/resource/Greek_Awards>; }
# SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> https://dbpedia.org/resource/Oscars UNION SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> https://dbpedia.org/resource/Nobel_Prlize ; }
# SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/resource/Oscar_award> . ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> ?uri  . FILTER(?uri = <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>) } UNION SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> ?uri  . FILTER(?uri = <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>) }
# SELECT * WHERE { ?a <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Award>. ?a <http://dbpedia.org/resource/Oscar> ?o1. FILTER(strstarts(lcase(?z), 'oscar')) . ?a <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Award>. ?a <http://dbpedia.org/resource/Nobel_Prize> ?o2. FILTER(strstarts(lcase(?z), 'nobel prize')) . }}
#
# SELECT DISTINCT ?uri WHERE {{?x <http://dbpedia.org/ontology/award> <http://dbpedia.org/resource/Golden_Globe_Award> . ?x <http://dbpedia.org/property/awards> ?uri. ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Award>} UNION SELECT DISTINCT ?uri WHERE {{?x <http://dbpedia.org/ontology/award> <http://dbpedia.org/resource/Nobel_Prize> . ?x <http://dbpedia.org/property/awards> ?uri. ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://sbidpedia.org/ontology/Award>}}
# SELECT DISTINCT ?uri WHERE { ?x <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> 'Award' . ?x <http://dbpedia.org/property/awards> ?uri. FILTER regex(str(?uri), 'Oscar') OR regex(str(?uri), 'Nobel Prize') }
# SELECT DISTINCT ?uri WHERE { ?x <http://dbpedia.org/ontology/award> <http://dbpedia.org/resource/Oscar> . ?x <http://dbpedia.org/property/awards> ?y  . ?y <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Award> . FILTER (STRSTARTS(str(?y), 'Oscar') && STRLEN(?y) >= 1 AND STRIP(STRSUBSTNF(str(?y), '/', ''), '/') IN ('Prize'))} UNION ?x <http://dbpedia.org/ontology/award> <http://dbpedia.org/resource/Nobel_Library> . ?x <http://dbpedia.org/property/awards> ?z  . ?z <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Award> . FILTER (STRLEN(?z) >= 1)
# SELECT DISTINCT ?uri WHERE {?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/resource/Golden_Globe_Award,http://dbpedia.org/resource/Nobel_prize_winner>}
